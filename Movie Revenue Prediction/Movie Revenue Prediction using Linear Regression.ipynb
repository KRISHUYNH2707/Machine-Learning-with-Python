# %% [markdown]
# ## Gather data
#
# * Data on feature -> movie bugest in USD
# * Data on target -> movie revenue in USD

# %%
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('cost_revenue_clean.csv')

# %%
data.head()
# Out:
#    production_budget_usd  worldwide_gross_usd
# 0                1000000                   26
# 1                  10000                  401
# 2                 400000                  423
# 3                 750000                  450
# 4                  10000                  527

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
X = pd.DataFrame(data, columns=["production_budget_usd"])
y = pd.DataFrame(data, columns=["worldwide_gross_usd"])

# %%
X
# Out:
#       production_budget_usd
# 0                   1000000
# 1                     10000
# 2                    400000
# 3                    750000
# 4                     10000
# ...                     ...
# 5029              225000000
# 5030              215000000
# 5031              306000000
# 5032              200000000
# 5033              425000000
#
# [5034 rows x 1 columns]

# %%
y
# Out:
#       worldwide_gross_usd
# 0                      26
# 1                     401
# 2                     423
# 3                     450
# 4                     527
# ...                   ...
# 5029           1519479547
# 5030           1671640593
# 5031           2058662225
# 5032           2207615668
# 5033           2783918982
#
# [5034 rows x 1 columns]

# %%
plt.figure(figsize=(10,6))
plt.scatter(X,y, alpha=0.3)
plt.title("Film Cost vs Global Budget")
plt.xlabel("Product Budget $")
plt.ylabel("Worldwide Gross $ ")
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.show()

# %%
regression = LinearRegression()

# %%
regression.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
slope = regression.coef_ # Slope coeffiecient

# %%
intercept = regression.intercept_ #intercept coefficient

# %%
plt.figure(figsize=(10,6))
plt.scatter(X,y, alpha=0.3)
plt.plot(X, regression.predict(X), color='red', linewidth=4)

plt.title("Film Cost vs Global Budget")
plt.xlabel("Product Budget $")
plt.ylabel("Worldwide Gross $ ")
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.show()
